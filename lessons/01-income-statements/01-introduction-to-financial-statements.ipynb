# %% [markdown]
# # Introduction to financial statements
# _Financial Forecasting in Python_
#
# **Lesson:** 1-1. Introduction to Financial Statements
#
#
# 📄 Notes: [01 - Introduction to Financial Statements](docs/01%20-%20Introduction%20to%20Financial%20Statements.md)

# %% [markdown]
# ## Overview
#
# What the income statement, balance sheet and cash flow statement tell us.

# %% [markdown]
# ## Learning objectives
#
# - Calculating gross profit
# - Calculating net profit

# %% [markdown]
# ## Setup

# %%
import sys; sys.path.insert(0, '../../src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ffp import sample_prices, error_report  # shared helpers

# %% [markdown]
# ## Walkthrough

# %%
# TODO: lesson code here
# prices = sample_prices()
# prices.plot(figsize=(10, 4), title='Sample price series')
# plt.show()

# %% [markdown]
# ## Exercises
#
# **Exercise 1 - Calculating gross profit**
#
# Gross profit is the amount of money you generated in sales minus the cost of selling those goods (Also know as Cost of Goods Sold or COGS).
# COGS does not include administration or marketing costs, only costs directly related to production or providing the good or service, so Gross Profit is a good metric to see the core profitability of any product\service.
#
# $$\text{Gross Profit} = \text{Total Sales Value} - \text{Total COGS}$$
#
# Gross profit margin is the gross profit expressed as a percentage of sales, which is valuable for analysis and decision making.
#
# $$\text{Gross Profit Margin} = \frac{\text{Gross Profit}}{\text{Sales Value}}$$
#
# _As the manager of a factory, you have been asked to check the gross profit forecast for the following year._

# %%
# Set the sales variable to 8000
sales = 8000

# Set the cost of goods sold (cogs) variable to 5400
cogs = 5400

# Calculate the gross profit (gross_profit)
gross_profit = sales - cogs

# Print the gross profit
print("The gross profit is {}.".format(gross_profit))
# Out:
# The gross profit is 2600.

# %% [markdown]
# **Exercise 2 - Calculating Net Profit**
#
# The net profit includes all the other costs (and all other income) that may incur or earn that is not directly related to the product. For example the salary of the accountant who prepares your invoices, the advertising budget, travel expenses, etc.
#
# So, how do we calculate this?
#
# We start by setting a list for all the items that we want to include in the net profit calculation and calling the list "other operating expenses" or "opex". To keep it simple we will not go into any tax or exceptional expenses or income. The simplified calculation is:
#
# $$\text{Net Profit} = \text{Gross Profit} - \text{Other Operating Expences}$$

# %%
# Create and print the opex list

admin = 700
travel = 250
training = 130
marketing = 280
insurance = 150

opex = [travel, training, marketing, insurance]
print(opex)

# Calculate and print net profit
net_profit = gross_profit - sum(opex)
print("The net profit is {}.".format(net_profit))
# Out:
# [250, 130, 280, 150]
# The net profit is 1790.

# %% [markdown]
# ## Summary
#
# Recap the key points see in lessons/01-income-statements/docs/01 - Introduction to Financial Statements.md
